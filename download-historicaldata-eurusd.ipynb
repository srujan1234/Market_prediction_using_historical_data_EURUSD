# %% [markdown]
# **Downloading Historical Forex Data:**
# - A series of commands, executed using `npx dukascopy-node`, are used to download historical Forex data for the "EUR/USD" currency pair in various timeframes.
# - Data is downloaded for different timeframes, ranging from minutes (m1, m5, m15, m30) to hours (h1, h4), and even longer timeframes such as daily (d1), monthly (mn1), and even tick data.
# - These commands fetch historical Forex data starting from May 4, 2003, and extend up to various end dates, depending on the timeframe.
#
# **File Deletion:**
# - The notebook also includes Python code to delete a specific file. The file path specified for deletion if anyfiles downloaded twice
# - The code uses the `os` module to perform the file deletion task. It first checks if the specified file exists with `os.path.exists(file_path)`.
# - If the file is found, it is deleted using `os.remove(file_path)`.
# - A message is printed indicating whether the file was successfully deleted or not.

# %%
# !npx dukascopy-node -i eurusd -from 2003-05-04 -t m1 -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
# !npx dukascopy-node -i eurusd -from 2003-05-04 -t m5 -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
# !npx dukascopy-node -i eurusd -from 2003-05-04 -t m15 -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
# !npx dukascopy-node -i eurusd -from 2003-05-04 -t m30 -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
# !npx dukascopy-node -i eurusd -from 2003-05-04 -t h1 -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
# !npx dukascopy-node -i eurusd -from 2003-05-04 -t h4 -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
# !npx dukascopy-node -i eurusd -from 1973-03-01 -t d1 -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
# !npx dukascopy-node -i eurusd -from 1973-03-01 -t mn1 -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
# !npx dukascopy-node -i eurusd -from 2003-05-04 -t tick -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
# !npx dukascopy-node -i eurusd -from 2003-05-04 -t s1 -f csv -bs 100 -bp 1000 --volumes true --flats true

# %%
import os

# Specify the file path you want to delete
file_path = "/kaggle/working/download/eurusd-m30-bid-2003-05-04T21-2023-10-31T11:23.csv"

# Check if the file exists before attempting to delete it
if os.path.exists(file_path):
    os.remove(file_path)
    print("File deleted successfully")
else:
    print("File not found")

# Optionally, you can also use the following to suppress the confirmation prompt
# os.remove(file_path)
